# %% [markdown]
# <a href="https://colab.research.google.com/github/maycgr/Analise-De-Dados-EBAC/blob/main/Profissao_Analista_de_dados_M40_ExercicioMayara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Computação em Nuvem III
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução;</li>
#   <li>Apache Spark;</li>
#   <li>Data Wrangling com Spark.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Apache Spark

# %% [markdown]
# Replique as atividades do item 2.1 e 2.2 para instalar e configurar um cluster Apache Spark na máquina virtual do Google Colab.

# %%
# %%capture
# !wget -q https://archive.apache.org/dist/spark/spark-3.0.0/spark-3.0.0-bin-hadoop2.7.tgz
# !tar xf spark-3.0.0-bin-hadoop2.7.tgz && rm spark-3.0.0-bin-hadoop2.7.tgz

# %%
# %%capture
# !apt-get remove openjdk*
# !apt-get update --fix-missing
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
# !pip install -q pyspark==3.5
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 13.8 MB/s eta 0:00:00
# ...

# %%
import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop2.7"

# %%
# !pip install -q findspark==1.4.2

# %%
import findspark

findspark.init()

# %% [markdown]
# ## 2\. Data Wrangling

# %% [markdown]
# A base de dados presente neste [link](https://www.kaggle.com/datasets/bank-of-england/a-millennium-of-macroeconomic-data) contem dados macroeconômicos sobre o Reino Unido desde o século 13.

# %% [markdown]
# **2.1\. Data**

# %% [markdown]
# Faça o download dos dados utilizando a máquina virutal do Google Colab com o código abaixo.

# %%
# !wget -q "https://raw.githubusercontent.com/cluster-apps-on-docker/spark-standalone-cluster-on-docker/master/build/workspace/data/uk-macroeconomic-data.csv" -O "uk-macroeconomic-data.csv"

# %% [markdown]
# **2.2. Wrangling**

# %% [markdown]
# Processe os dados para que a base de dados final apresente os valores da taxa de desemprego (`Unemployment rate`) e população (`Population (GB+NI)`) estejam ordenados por ano decrescente:

# %% [markdown]
# ```csv
# year,population,unemployment_rate
# ...,...,...
# ```

# %% [markdown]
# Para isso, utilize:

# %% [markdown]
#  - Pandas

# %%
import pandas as pd

dados_macroeconomicos_UK = pd.read_csv('uk-macroeconomic-data.csv')
dados_macroeconomicos_UK.head(3)
# Out:
#   Description      Real GDP of England at market prices  \
# 0       Units  £mn, Chained Volume measure, 2013 prices
# 1        1209                                       NaN
# 2        1210                                       NaN
#
#         Real GDP of England at factor cost   \
# 0  £mn, Chained Volume measure, 2013 prices
# 1                                       NaN
# 2                                       NaN
#
#   Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders  \
# 0           £mn, Chained Volume measure, 2013 prices
# 1                                                NaN
# 2                                                NaN
#
#   Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders  \
# 0           £mn, Chained Volume measure, 2013 prices
# 1                                                NaN
# 2                                                NaN
#
# ...

# %%
dados_macroeconomicos_UK = dados_macroeconomicos_UK.loc[1:]
colunas_interesse = ['Description', 'Population (GB+NI)', 'Unemployment rate']
dados_macroeconomicos_UK = dados_macroeconomicos_UK[colunas_interesse].dropna().sort_values('Description', ascending=False)
dados_macroeconomicos_UK
# Out:
#     Description Population (GB+NI) Unemployment rate
# 808        2016              65573              4.90
# 807        2015              65110              5.38
# 806        2014              64597              6.18
# 805        2013              64106              7.61
# 804        2012              63705              7.97
# ..          ...                ...               ...
# 651        1859              24138              3.27
# 650        1858              23914              5.23
# 649        1857              23689              3.95
# 648        1856              23466              3.52
# 647        1855              23241              3.73
#
# [162 rows x 3 columns]

# %%
dados_macroeconomicos_UK.columns = ['Year', 'Population', 'Unemployment rate']
dados_macroeconomicos_UK.head(3)
# Out:
#      Year Population Unemployment rate
# 808  2016      65573              4.90
# 807  2015      65110              5.38
# 806  2014      64597              6.18

# %%
dados_macroeconomicos_UK.to_csv('uk-macroeconomic-data-cleaned.csv', index=False)

# %% [markdown]
#  - PySpark

# %%
import os
os.environ["SPARK_HOME"] = "/content/spark-3.0.0-bin-hadoop2.7"

# %%
from pyspark import SparkSession

spark = SparkSession.builder.master("local[*]").appName("pyspark-notebook").getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9f91e062e9b6> in <cell line: 0>()
# ----> 1 from pyspark import SparkSession
#       2
#       3 spark = SparkSession.builder.master("local[*]").appName("pyspark-notebook").getOrCreate()
#
# /content/spark-3.0.0-bin-hadoop2.7/python/pyspark/__init__.py in <module>
#      49
#      50 from pyspark.conf import SparkConf
# ---> 51 from pyspark.context import SparkContext
#      52 from pyspark.rdd import RDD, RDDBarrier
#      53 from pyspark.files import SparkFiles
#
# /content/spark-3.0.0-bin-hadoop2.7/python/pyspark/context.py in <module>
#      28 from py4j.java_gateway import is_instance_of
#      29
# ---> 30 from pyspark import accumulators
#      31 from pyspark.accumulators import Accumulator
#      32 from pyspark.broadcast import Broadcast, BroadcastPickleRegistry
#
# ...

# %%
dados_macroeconomicos_UK = spark.read.csv(
    path='uk-macroeconomic-data.csv',
    sep=',',
    header=True
)

dados_macroeconomicos_UK.show(n=4)
# Out:
# +-----------+------------------------------------+-----------------------------------+-------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------+------------------------------------------------------------------------------+----------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------+--------------------+--------------------+--------------------------+-------------------------------------------------+--------------------+--------------------+---------------------------------------+-------------------------------+---------------------------------+------------------+--------------------+----------+-----------------+---------------------------+----------------------------
# ...

# %%
dados_macroeconomicos_UK.printSchema()
# Out:
# root
#  |-- Description: string (nullable = true)
#  |-- Real GDP of England at market prices: string (nullable = true)
#  |-- Real GDP of England at factor cost : string (nullable = true)
#  |-- Real UK GDP at market prices, geographically-consistent estimate based on post-1922 borders: string (nullable = true)
#  |-- Real UK GDP at factor cost, geographically-consistent estimate based on post-1922 borders: string (nullable = true)
#  |-- Index of real UK GDP at factor cost - based on changing political boundaries, : string (nullable = true)
#  |-- Composite estimate of English and (geographically-consistent) UK real GDP at factor cost: string (nullable = true)
#  |-- HP-filter of log of real composite estimate of English and UK real GDP at factor cost: string (nullable = true)
#  |-- Real UK gross disposable national income at market prices, constant border estimate: string (nullable = true)
#  |-- Real consumption: string (nullable = true)
# ...

# %%
dados_macroeconomicos_UK = dados_macroeconomicos_UK.select(
    ['Description', 'Population (GB+NI)', 'Unemployment rate']
)

# %%
dados_macroeconomicos_UK = dados_macroeconomicos_UK.\
    withColumnRenamed('Description', 'Year').\
    withColumnRenamed('Population (GB+NI)', 'Population')

# %%
dados_macroeconomicos_UK.show(n=4)
# Out:
# +-----+----------+-----------------+
# | Year|Population|Unemployment rate|
# +-----+----------+-----------------+
# |Units|      000s|                %|
# | 1209|      null|             null|
# | 1210|      null|             null|
# | 1211|      null|             null|
# +-----+----------+-----------------+
# only showing top 4 rows

# %%
from pyspark.sql.functions import broadcast

# %%
dados_macroeconomicos_UK_linha_descricao = dados_macroeconomicos_UK.\
    filter(dados_macroeconomicos_UK['Year'] == 'Units')

# %%
dados_macroeconomicos_UK = dados_macroeconomicos_UK.join(
    other=broadcast(dados_macroeconomicos_UK_linha_descricao),
    on=['year'],
    how='left_anti'
)

# %%
dados_macroeconomicos_UK.show(n=3)
# Out:
# +----+----------+-----------------+
# |Year|Population|Unemployment rate|
# +----+----------+-----------------+
# |1209|      null|             null|
# |1210|      null|             null|
# |1211|      null|             null|
# +----+----------+-----------------+
# only showing top 3 rows

# %%
dados_macroeconomicos_UK.sort(dados_macroeconomicos_UK.Year.desc()).show(n=3)
# Out:
# +----+----------+-----------------+
# |Year|Population|Unemployment rate|
# +----+----------+-----------------+
# |2016|     65573|             4.90|
# |2015|     65110|             5.38|
# |2014|     64597|             6.18|
# +----+----------+-----------------+
# only showing top 3 rows

# %%
dados_macroeconomicos_UK.\
    write.csv(path="uk-macroeconomic-data-clean", sep=",", header=True, mode="overwrite")
