# %% [markdown]
# <a href="https://colab.research.google.com/github/maycgr/Analise-De-Dados-EBAC/blob/main/PROJETO_EADC_MAYARA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploração e análise de dados de crédito com SQL**
# by Mayara

# %% [markdown]
# ## Os dados:
#
# Os dados representam informações de clientes de um banco e contam com as seguintes colunas:
#
#     idade = idade do cliente
#     sexo = sexo do cliente (F ou M)
#     dependentes = número de dependentes do cliente
#     escolaridade = nível de escolaridade do clientes
#     salario_anual = faixa salarial do cliente
#     tipo_cartao = tipo de cartao do cliente
#     qtd_produtos = quantidade de produtos comprados nos últimos 12 meses
#     iteracoes_12m = quantidade de iterações/transacoes nos ultimos 12 meses
#     meses_inativo_12m = quantidade de meses que o cliente ficou inativo
#     limite_credito = limite de credito do cliente
#     valor_transacoes_12m = valor das transações dos ultimos 12 meses
#     qtd_transacoes_12m = quantidade de transacoes dos ultimos 12 meses
#
# A tabela foi criada no AWS Athena junto com o S3 Bucket com uma versão dos dados disponibilizados em: https://github.com/andre-marcos-perez/ebac-course-utils/tree/main/dataset

# %% [markdown]
# # Exploração de dados:
#
# Nesta primeira query vamos entender como está a nossa materia prima.
#
# QUERY:
#
# ![query2.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query2results.png](data:image/png;base64,...)
#
# *PS* :A base de dados do link acima contém mais linhas do que a seleção utilizada para a análise.

# %% [markdown]
# **Como são os dados:**
#
# QUERY:
#
# ![query3.png](data:image/png;base64,...)
#
# Rsultado:
#
# ![query3results.png](data:image/png;base64,...)
#
# Notamos que alguns resultados aparecem como nulos (valor na) na tabela. Vamos olha de perto o valor de cada coluna.

# %% [markdown]
# **Quais os tipos de cada dado**
#
# QUERY:
#
# ![query1.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query1results.png](data:image/png;base64,...)
#
# Agora que já descobrimos quais são os tipos de dados vamos olhar mais de perto os dados não numéricos.

# %% [markdown]
# **Quais são os tipos de escolaridade disponíveis no dataset?**
#
# QUERY:
#
# ![query4.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query4results.png](data:image/png;base64,...)
#
# Os dados contém varios tipos de escolaridade e entre eles valores nulos (na).

# %% [markdown]
# **Quais os tipos de salarial anual contem no dataset?**
#
# QUERY:
#
# ![QUERY10.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query5results.png](data:image/png;base64,...)

# %% [markdown]
# **Quais os tipos de estado_civil no dataset?**
#
# QUERY:
#
# ![query11.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query11results.png](data:image/png;base64,...)

# %% [markdown]
# **Quais são os tipos de cartão?**
#
# QUERY:
#
# ![query12.png](data:image/png;base64,...)
#
# Resuldo:
#
# ![query12results.png](data:image/png;base64,...)

# %% [markdown]
# # Analise de dados
#  Uma vez que exploramos os dados, vamos analisar quais as informações temos no bando de dados.
#
#
# **Qual a quantidade de clientes em cada faixa salarial anual?**
#
# QUERY:
#
# ![query5.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query5results.png](data:image/png;base64,...)
#
# Podemos perceber que os clientes que ganham abaixo de 40k/anual estão em maior número e 235 clientes estão com as informaçoẽs sobre o salarial anual incompleta.

# %% [markdown]
# **Quantos clientes são homens e quantos são mulheres?**
#
# QUERY:
#
# ![query6.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query6results.png](data:image/png;base64,...)
#
# ![graficofm.png](data:image/png;base64,...)
#
# A grande maioria dos clientes são homens, totalizando 61% do total.

# %% [markdown]
# **Qual a media de idade entre os clientes?**
#
# QUERY:
#
# ![QUERY13.png](data:image/png;base64,...)
#
# Resultado:
#
# ![QUERY13RESULTS.png](data:image/png;base64,...)
#
# A media de idade entre os sexos acemelham-se tendo em vista que a idade minima são as mesmas e a idade máxima não tem diferenças tão distantes.

# %% [markdown]
# **Quais são os limites de crédito por escoliridade, tipo de cartão e sexo ?**
#
# QUERY:
#
# ![query7.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query7results.png](data:image/png;base64,...)
#
# Conseguimos perceber que o limite de credito e a escolaridade não tem relação, tanto os clientes com doudorado e os clientes com ensino medio conseguem ter o mesmo limite de crédito. O mesmo vale para o tipo de cartão, todos os tipos estão entre os valores mais altos.
# Os homens são maioria entre os clientes com o limite alto.

# %% [markdown]
# **Qual a média de gasto entre os clientes ?**
#
# QUERY:
#
# ![query8.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query8results.png](data:image/png;base64,...)
#
# A media de gasto entre homens e mulheres são similares.

# %% [markdown]
# **Quantos produtos em media é comprado pelos clientes ?**
#
# QUERY:
#
# ![query9.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query9results.png](data:image/png;base64,...)
#
# A media de produtos adquiridos pelos clientes é de 4 ou mais produtos por compra, os homens são os que mais compram e os clientes que ganham mais de 40k são maioria entres os que mais compram produtos.

# %% [markdown]
# # CONCLUSÃO
#
# A análise mostra que a maioria dos clientes ganha até 40 mil por ano, e a maioria também é composta por homens. A escolaridade não parece ter muita influência no tipo de cartão nem no limite oferecido. Os homens costumam ter os limites mais altos, enquanto as mulheres, em geral, têm limites mais baixos. Entre esses limites menores, nenhum cliente possui o cartão platinum. A faixa salarial, por outro lado, afeta diretamente o valor do crédito liberado. Além disso, não há mulheres com salário anual acima de 60 mil.
