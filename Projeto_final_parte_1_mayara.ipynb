# %% [markdown]
# <a href="https://colab.research.google.com/github/maycgr/Analise-De-Dados-EBAC/blob/main/Projeto_final_parte_1_mayara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Pipeline de Dados do Telegram I
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Contexto;</li>
#   <li>Telegram;</li>
#   <li>Dados.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 1\. Telegram.

# %% [markdown]
# Replique as atividades da aula 2.

# %% [markdown]
# 1.1. Crie uma conta no **Telegram** caso não possua uma e faça o login na versão web da ferramenta através desse [link](https://web.telegram.org).

# %% [markdown]
# 1.2. Crie um *bot*.

# %% [markdown]
# ![telegram1.png](data:image/png;base64,...)

# %% [markdown]
# 1.3. Crie um grupo e adicione o *bot*.

# %% [markdown]
# ![telegram2.png](data:image/png;base64,...)

# %% [markdown]
# 1.4. Torne o *bot* administrador do grupo.

# %% [markdown]
# ![telegram3.png](data:image/png;base64,...)

# %% [markdown]
# 1.5. Desabilite a opção de adicionar o *bot* a novos grupos.

# %% [markdown]
# ![telegram4.png](data:image/png;base64,...)

# %% [markdown]
# 1.6. Envie diversos tipos de mensagens no grupo (text, imagem, arquivos, video, áudio, etc.) e as consuma utilizand a API de *bots* do **Telegram**.

# %% [markdown]
# ![telegram5.png](data:image/png;base64,...)

# %% [markdown]
# > **Nota:** A documentação completa da API pode ser encontrada neste [link](https://core.telegram.org/bots/api)

# %%
from getpass import getpass

token = getpass()
# Out:
# ··········

# %%
import json

import requests

base_url = f'https://api.telegram.org/bot{token}'

# %%
#Colendo informações do bot
response = requests.get(url=f'{base_url}/getMe')
print(f'{base_url}/getMe')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# https://api.telegram.org/bot7940162926:AAG_2sZpDXdxDtOkQMAxWksvBwWYU72P1fM/getMe
# {
#   "ok": true,
#   "result": {
#     "id": 7940162926,
#     "is_bot": true,
#     "first_name": "m43_ebac_bot",
#     "username": "m43_ebac_mayara_bot",
#     "can_join_groups": false,
#     "can_read_all_group_messages": false,
#     "supports_inline_queries": false,
#     "can_connect_to_business": false,
#     "has_main_web_app": false
#   }
# }

# %%
response = requests.get(url=f'{base_url}/getUpdates')

print(json.dumps(json.loads(response.text), indent=2))
# Out:
# {
#   "ok": true,
#   "result": [
#     {
#       "update_id": 924147211,
#       "my_chat_member": {
#         "chat": {
#           "id": -1002313386486,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730553878,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "administrator",
#           "can_be_edited": false,
#           "can_manage_chat": true,
#           "can_change_info": false,
#           "can_delete_messages": false,
#           "can_invite_users": false,
#           "can_restrict_members": false,
#           "can_pin_messages": true,
#           "can_manage_topics": false,
#           "can_promote_members": false,
#           "can_manage_video_chats": false,
#           "can_post_stories": false,
#           "can_edit_stories": false,
#           "can_delete_stories": false,
#           "is_anonymous": false,
#           "can_manage_voice_chats": false
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         }
#       }
#     },
#     {
#       "update_id": 924147212,
#       "message": {
#         "message_id": 10,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002313386486,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1730554001,
#         "left_chat_participant": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "left_chat_member": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         }
#       }
#     },
#     {
#       "update_id": 924147213,
#       "my_chat_member": {
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730554074,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "left"
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         }
#       }
#     },
#     {
#       "update_id": 924147214,
#       "message": {
#         "message_id": 4,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554074,
#         "new_chat_participant": {
#           "id": 7940162926,
#           "is_bot": true,
#           "first_name": "m43_ebac_bot",
#           "username": "m43_ebac_mayara_bot"
#         },
#         "new_chat_member": {
#           "id": 7940162926,
#           "is_bot": true,
#           "first_name": "m43_ebac_bot",
#           "username": "m43_ebac_mayara_bot"
#         },
#         "new_chat_members": [
#           {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           }
#         ]
#       }
#     },
#     {
#       "update_id": 924147215,
#       "my_chat_member": {
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730554107,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "administrator",
#           "can_be_edited": false,
#           "can_manage_chat": true,
#           "can_change_info": true,
#           "can_delete_messages": true,
#           "can_invite_users": true,
#           "can_restrict_members": true,
#           "can_pin_messages": true,
#           "can_promote_members": false,
#           "can_manage_video_chats": true,
#           "can_post_stories": false,
#           "can_edit_stories": false,
#           "can_delete_stories": false,
#           "is_anonymous": false,
#           "can_manage_voice_chats": true
#         }
#       }
#     },
#     {
#       "update_id": 924147216,
#       "message": {
#         "message_id": 5,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554124,
#         "text": "Oi"
#       }
#     },
#     {
#       "update_id": 924147217,
#       "message": {
#         "message_id": 6,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554130,
#         "text": "Tubo bem"
#       }
#     },
#     {
#       "update_id": 924147218,
#       "message": {
#         "message_id": 7,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554137,
#         "voice": {
#           "duration": 3,
#           "mime_type": "audio/ogg",
#           "file_id": "AwACAgEAAxkBAAMHZyYpGQIOz96mSxKEBA9plJoixPsAArYDAAIIMDBFgNDuKgQkEwo2BA",
#           "file_unique_id": "AgADtgMAAggwMEU",
#           "file_size": 15282
#         }
#       }
#     },
#     {
#       "update_id": 924147219,
#       "message": {
#         "message_id": 8,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554154,
#         "photo": [
#           {
#             "file_id": "AgACAgEAAxkBAAMIZyYpKvwq2KqumjjsjFa6zpAGcv4AAuqtMRuLazFFKSMIGLdXaTgBAAMCAANzAAM2BA",
#             "file_unique_id": "AQAD6q0xG4trMUV4",
#             "file_size": 1401,
#             "width": 51,
#             "height": 90
#           },
#           {
#             "file_id": "AgACAgEAAxkBAAMIZyYpKvwq2KqumjjsjFa6zpAGcv4AAuqtMRuLazFFKSMIGLdXaTgBAAMCAANtAAM2BA",
#             "file_unique_id": "AQAD6q0xG4trMUVy",
#             "file_size": 20080,
#             "width": 180,
#             "height": 320
#           },
#           {
#             "file_id": "AgACAgEAAxkBAAMIZyYpKvwq2KqumjjsjFa6zpAGcv4AAuqtMRuLazFFKSMIGLdXaTgBAAMCAAN4AAM2BA",
#             "file_unique_id": "AQAD6q0xG4trMUV9",
#             "file_size": 92190,
#             "width": 450,
#             "height": 800
#           },
#           {
#             "file_id": "AgACAgEAAxkBAAMIZyYpKvwq2KqumjjsjFa6zpAGcv4AAuqtMRuLazFFKSMIGLdXaTgBAAMCAAN5AAM2BA",
#             "file_unique_id": "AQAD6q0xG4trMUV-",
#             "file_size": 128015,
#             "width": 720,
#             "height": 1280
#           }
#         ]
#       }
#     },
#     {
#       "update_id": 924147220,
#       "message": {
#         "message_id": 9,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730554540,
#         "text": "hahaha"
#       }
#     },
#     {
#       "update_id": 924147221,
#       "message": {
#         "message_id": 10,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4538830452,
#           "title": "Ebac m43 bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730557998,
#         "left_chat_participant": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "left_chat_member": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         }
#       }
#     },
#     {
#       "update_id": 924147222,
#       "my_chat_member": {
#         "chat": {
#           "id": -4550706913,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730558074,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "left"
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         }
#       }
#     },
#     {
#       "update_id": 924147223,
#       "message": {
#         "message_id": 11,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4550706913,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "group",
#           "all_members_are_administrators": true
#         },
#         "date": 1730558074,
#         "new_chat_participant": {
#           "id": 7940162926,
#           "is_bot": true,
#           "first_name": "m43_ebac_bot",
#           "username": "m43_ebac_mayara_bot"
#         },
#         "new_chat_member": {
#           "id": 7940162926,
#           "is_bot": true,
#           "first_name": "m43_ebac_bot",
#           "username": "m43_ebac_mayara_bot"
#         },
#         "new_chat_members": [
#           {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           }
#         ]
#       }
#     },
#     {
#       "update_id": 924147224,
#       "my_chat_member": {
#         "chat": {
#           "id": -1002252615547,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730558088,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "left"
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         }
#       }
#     },
#     {
#       "update_id": 924147225,
#       "message": {
#         "message_id": 1,
#         "from": {
#           "id": 1087968824,
#           "is_bot": true,
#           "first_name": "Group",
#           "username": "GroupAnonymousBot"
#         },
#         "sender_chat": {
#           "id": -1002252615547,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "chat": {
#           "id": -1002252615547,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "date": 1730558088,
#         "migrate_from_chat_id": -4550706913
#       }
#     },
#     {
#       "update_id": 924147226,
#       "message": {
#         "message_id": 12,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -4550706913,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "group",
#           "all_members_are_administrators": false
#         },
#         "date": 1730558089,
#         "migrate_to_chat_id": -1002252615547
#       }
#     },
#     {
#       "update_id": 924147227,
#       "my_chat_member": {
#         "chat": {
#           "id": -1002252615547,
#           "title": "Mayara, m43_ebac_bot",
#           "type": "supergroup"
#         },
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "date": 1730558089,
#         "old_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "member"
#         },
#         "new_chat_member": {
#           "user": {
#             "id": 7940162926,
#             "is_bot": true,
#             "first_name": "m43_ebac_bot",
#             "username": "m43_ebac_mayara_bot"
#           },
#           "status": "administrator",
#           "can_be_edited": false,
#           "can_manage_chat": true,
#           "can_change_info": true,
#           "can_delete_messages": true,
#           "can_invite_users": true,
#           "can_restrict_members": true,
#           "can_pin_messages": true,
#           "can_manage_topics": false,
#           "can_promote_members": false,
#           "can_manage_video_chats": true,
#           "can_post_stories": false,
#           "can_edit_stories": false,
#           "can_delete_stories": false,
#           "is_anonymous": false,
#           "can_manage_voice_chats": true
#         }
#       }
#     },
#     {
#       "update_id": 924147228,
#       "message": {
#         "message_id": 2,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002252615547,
#           "title": "Ebac 43 bot",
#           "type": "supergroup"
#         },
#         "date": 1730558105,
#         "new_chat_title": "Ebac 43 bot"
#       }
#     },
#     {
#       "update_id": 924147229,
#       "message": {
#         "message_id": 3,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002252615547,
#           "title": "Ebac 43 bot",
#           "type": "supergroup"
#         },
#         "date": 1730558113,
#         "text": "Ola mundo"
#       }
#     },
#     {
#       "update_id": 924147230,
#       "message": {
#         "message_id": 4,
#         "from": {
#           "id": 6948498137,
#           "is_bot": false,
#           "first_name": "Mayara",
#           "last_name": "Graciano",
#           "language_code": "pt-br"
#         },
#         "chat": {
#           "id": -1002252615547,
#           "title": "Ebac 43 bot",
#           "type": "supergroup"
#         },
#         "date": 1730558115,
#         "text": "haha"
#       }
#     }
#   ]
# }
