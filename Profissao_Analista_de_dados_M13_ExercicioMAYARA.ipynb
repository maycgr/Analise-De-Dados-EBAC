# %% [markdown]
# <a href="https://colab.research.google.com/github/maycgr/Analise-De-Dados-EBAC/blob/main/Profissao_Analista_de_dados_M13_ExercicioMAYARA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Análise de Dados: Data Wrangling II
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Agregação e Ordenação;</li>
#   <li>Combinação;</li>
#   <li>Técnicas Avançadas.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# Neste exercícios, vamos trabalhar com dados geográficos, demográficos e econômicos do Brasil. Vamos manipular e combinar dados de duas frentes distintas para poder responder perguntas de negócios.

# %% [markdown]
# ## 1\. Data Wrangling

# %% [markdown]
# ### **1.1. Estados**

# %% [markdown]
# O arquivo `estados-bruto.xml` contém informações sobre estados (nome, sigla e região). **Carregue-o na máquina virtual do Google Colab**. Um arquivo do tipo XML é similar a um arquivo do tipo HTML, exemplo do estado do Acre:

# %% [markdown]
# ```xml
# <ESTADO>
#   <ID>1</ID>
#   <NOME>ACRE</NOME>
#   <IDCAPITAL>16</IDCAPITAL>
#   <SIGLA>AC</SIGLA>
#   <REGIAO>NORTE</REGIAO>
# </ESTADO>
# ```

# %% [markdown]
# Utilize o pacote Python `beautifulsoup4` para extrair os dados do arquivo `estados-bruto.xml` providenciado. Salve os dados extraidos no arquivo `estados-limpo.csv` separado por `;`. Exemplo das três primeiras linhas mais o cabeçalho:
#
# ```
# estado;sigla;regiao
# ACRE;AC;NORTE
# ALAGOAS;AL;NORDESTE
# AMAPA;AP;NORTE
# ```
#
# **Dica**: Utilize o parser de xml chamado `lxml` do `beautifulsoup4`.

# %%
# ler o arquivo estados-bruto.xml, utilize o xml parser chamado lxml

from bs4 import BeautifulSoup

NOME_ARQUIVO_FONTE = 'estados-bruto.xml'

with open(NOME_ARQUIVO_FONTE, 'r', encoding='utf-8') as arquivo:
    fonte = BeautifulSoup(arquivo, 'lxml')
# Out:
# <ipython-input-63-a4d09009adae>:8: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   fonte = BeautifulSoup(arquivo, 'lxml')

# %%
# visualize os resultados

fonte
# Out:
# <?xml version="1.0" encoding="utf-8" ?><html><body><estados>
# <estado>
# <id>1</id>
# <nome>ACRE</nome>
# <idcapital>16</idcapital>
# <sigla>AC</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>2</id>
# <nome>ALAGOAS</nome>
# <idcapital>68</idcapital>
# <sigla>AL</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>3</id>
# <nome>AMAPA</nome>
# <idcapital>131</idcapital>
# <sigla>AP</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>4</id>
# <nome>AMAZONAS</nome>
# <idcapital>178</idcapital>
# <sigla>AM</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>5</id>
# <nome>BAHIA</nome>
# <idcapital>536</idcapital>
# <sigla>BA</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>6</id>
# <nome>CEARA</nome>
# <idcapital>676</idcapital>
# <sigla>CE</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>7</id>
# <nome>DISTRITO FEDERAL</nome>
# <idcapital>916</idcapital>
# <sigla>DF</sigla>
# <regiao>CENTRO-OESTE</regiao>
# </estado>
# <estado>
# <id>8</id>
# <nome>ESPIRITO SANTO</nome>
# <idcapital>879</idcapital>
# <sigla>ES</sigla>
# <regiao>SUDESTE</regiao>
# </estado>
# <estado>
# <id>9</id>
# <nome>GOIAS</nome>
# <idcapital>973</idcapital>
# <sigla>GO</sigla>
# <regiao>CENTRO-OESTE</regiao>
# </estado>
# <estado>
# <id>10</id>
# <nome>MARANHAO</nome>
# <idcapital>1309</idcapital>
# <sigla>MA</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>11</id>
# <nome>MATO GROSSO</nome>
# <idcapital>1374</idcapital>
# <sigla>MT</sigla>
# <regiao>CENTRO-OESTE</regiao>
# </estado>
# <estado>
# <id>12</id>
# <nome>MATO GROSSO DO SUL</nome>
# <idcapital>1485</idcapital>
# <sigla>MS</sigla>
# <regiao>CENTRO-OESTE</regiao>
# </estado>
# <estado>
# <id>13</id>
# <nome>PARA</nome>
# <idcapital>1561</idcapital>
# <sigla>PA</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>14</id>
# <nome>PARAIBA</nome>
# <idcapital>1779</idcapital>
# <sigla>PB</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>15</id>
# <nome>PARANA</nome>
# <idcapital>2002</idcapital>
# <sigla>PR</sigla>
# <regiao>SUL</regiao>
# </estado>
# <estado>
# <id>16</id>
# <nome>PERNAMBUCO</nome>
# <idcapital>2439</idcapital>
# <sigla>PE</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>17</id>
# <nome>PIAUI</nome>
# <idcapital>2704</idcapital>
# <sigla>PI</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>18</id>
# <nome>RIO DE JANEIRO</nome>
# <idcapital>2779</idcapital>
# <sigla>RJ</sigla>
# <regiao>SUDESTE</regiao>
# </estado>
# <estado>
# <id>19</id>
# <nome>RIO GRANDE DO NORTE</nome>
# <idcapital>2890</idcapital>
# <sigla>RN</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>20</id>
# <nome>RIO GRANDE DO SUL</nome>
# <idcapital>3273</idcapital>
# <sigla>RS</sigla>
# <regiao>SUL</regiao>
# </estado>
# <estado>
# <id>21</id>
# <nome>RONDONIA</nome>
# <idcapital>3473</idcapital>
# <sigla>RO</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>22</id>
# <nome>RORAIMA</nome>
# <idcapital>3491</idcapital>
# <sigla>RR</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>23</id>
# <nome>SANTA CATARINA</nome>
# <idcapital>3591</idcapital>
# <sigla>SC</sigla>
# <regiao>SUL</regiao>
# </estado>
# <estado>
# <id>24</id>
# <nome>SAO PAULO</nome>
# <idcapital>4361</idcapital>
# <sigla>SP</sigla>
# <regiao>SUDESTE</regiao>
# </estado>
# <estado>
# <id>25</id>
# <nome>SERGIPE</nome>
# <idcapital>4444</idcapital>
# <sigla>SE</sigla>
# <regiao>NORDESTE</regiao>
# </estado>
# <estado>
# <id>26</id>
# <nome>TOCANTINS</nome>
# <idcapital>4606</idcapital>
# <sigla>TO</sigla>
# <regiao>NORTE</regiao>
# </estado>
# <estado>
# <id>27</id>
# <nome>MINAS GERAIS</nome>
# <idcapital>4790</idcapital>
# <sigla>MG</sigla>
# <regiao>SUDESTE</regiao>
# </estado>
# </estados>
# </body></html>

# %%
# manipule os dados
import pandas as pd

dados_de_interesse = ['nome', 'sigla', 'regiao']

dados_limpos_estados_df = pd.DataFrame(columns = dados_de_interesse)

for nome_da_serie in dados_de_interesse:
   dados_limpos_estados_df[[nome_da_serie]] = fonte.find_all(nome_da_serie)

dados_limpos_estados_df.columns = ['estado'] + dados_de_interesse[1:3]

dados_limpos_estados_df
# Out:
#                  estado sigla        regiao
# 0                  ACRE    AC         NORTE
# 1               ALAGOAS    AL      NORDESTE
# 2                 AMAPA    AP         NORTE
# 3              AMAZONAS    AM         NORTE
# 4                 BAHIA    BA      NORDESTE
# 5                 CEARA    CE      NORDESTE
# 6      DISTRITO FEDERAL    DF  CENTRO-OESTE
# 7        ESPIRITO SANTO    ES       SUDESTE
# 8                 GOIAS    GO  CENTRO-OESTE
# 9              MARANHAO    MA      NORDESTE
# 10          MATO GROSSO    MT  CENTRO-OESTE
# 11   MATO GROSSO DO SUL    MS  CENTRO-OESTE
# 12                 PARA    PA         NORTE
# 13              PARAIBA    PB      NORDESTE
# 14               PARANA    PR           SUL
# 15           PERNAMBUCO    PE      NORDESTE
# 16                PIAUI    PI      NORDESTE
# 17       RIO DE JANEIRO    RJ       SUDESTE
# 18  RIO GRANDE DO NORTE    RN      NORDESTE
# 19    RIO GRANDE DO SUL    RS           SUL
# 20             RONDONIA    RO         NORTE
# 21              RORAIMA    RR         NORTE
# 22       SANTA CATARINA    SC           SUL
# 23            SAO PAULO    SP       SUDESTE
# 24              SERGIPE    SE      NORDESTE
# 25            TOCANTINS    TO         NORTE
# 26         MINAS GERAIS    MG       SUDESTE

# %%
# escrever o conteudo extraido no arquivo estados-limpo.csv separados por ;
import csv

NOME_ARQUIVO_DESTINO = 'estados-limpo.csv'

dados_limpos_estados_df.to_csv(NOME_ARQUIVO_DESTINO, sep=',' , encoding='utf8' , index=False)

# %% [markdown]
# ### **1.2. Cidades**

# %% [markdown]
# O arquivo `cidades-bruto.csv` contém informações demográficas e socioeconomicas das cidades do Brasil. **Carregue-o na máquina virtual do Google Colab**. Utilize o pacote Python `pandas` para extrair os dados do arquivo `cidades-bruto.xml` providenciado. Seguindo as seguintes especificações:

# %% [markdown]
# 1. Apenas dados do censo de 2010;
# 1. Apenas as colunas UF, Nome, PIB, Pop_est_2009 e PIB_percapita.

# %% [markdown]
# Salve os dados extraidos no arquivo `cidades-limpo.csv` separado por `;`. Exemplo das três primeiras linhas mais o cabeçalho:
#
# ```
# estado;cidade;populacao;pib;pib_percapita
# BAHIA;TREMEDAL;18433;57883.9921875;3140.23999023
# RIO GRANDE DO SUL;TURUÇU;4000;45723875;11430.96972656
# ESPIRITO SANTO;VITÓRIA;320156;19782628;61790.58984375
# ```

# %%
! wget https://static.lms.ebaconline.com.br/content-files/3e0d86cb-0ed9-4449-987a-9590509af238/original.csv
# Out:
# --2024-02-06 17:46:25--  https://static.lms.ebaconline.com.br/content-files/3e0d86cb-0ed9-4449-987a-9590509af238/original.csv
# Resolving static.lms.ebaconline.com.br (static.lms.ebaconline.com.br)... 18.230.109.84, 54.94.78.163
# Connecting to static.lms.ebaconline.com.br (static.lms.ebaconline.com.br)|18.230.109.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48513659 (46M) [application/octet-stream]
# Saving to: ‘original.csv’
#
# original.csv        100%[===================>]  46.27M  15.6MB/s    in 3.0s
#
# 2024-02-06 17:46:29 (15.6 MB/s) - ‘original.csv’ saved [48513659/48513659]

# %%
#Renomeando arquivo baixado
! mv original.csv cidades-bruto.csv

# %%
# ler o arquivo cidades-bruto.csv

import pandas as pd

NOME_ARQUIVO_FONTE_CIDADES = 'cidades-bruto.csv'

fonte_cidades = pd.read_csv(NOME_ARQUIVO_FONTE_CIDADES)

# %%
# visualize os resultados
fonte_cidades
# Out:
#                                                   FID   gid  \
# 0     vw_pib_percapita.fid-4514e25a_17aaa325034_-258f   215
# 1     vw_pib_percapita.fid-4514e25a_17aaa325034_-258e   306
# 2     vw_pib_percapita.fid-4514e25a_17aaa325034_-258d   900
# 3     vw_pib_percapita.fid-4514e25a_17aaa325034_-258c  3613
# 4     vw_pib_percapita.fid-4514e25a_17aaa325034_-258b  1028
# ...                                               ...   ...
# 5561   vw_pib_percapita.fid-4514e25a_17aaa325034_-eba  5254
# 5562   vw_pib_percapita.fid-4514e25a_17aaa325034_-eb9  2749
# 5563   vw_pib_percapita.fid-4514e25a_17aaa325034_-eb8  3779
# 5564   vw_pib_percapita.fid-4514e25a_17aaa325034_-eb7   617
# 5565   vw_pib_percapita.fid-4514e25a_17aaa325034_-eb6   672
#
#                      UF              nome   Censo           PIB  Pop_est_2009  \
# 0                 BAHIA          Tremedal  2010.0  5.788399e+04         18433
# 1     RIO GRANDE DO SUL            Turuçu  2010.0  4.572388e+04          4000
# 2        ESPIRITO SANTO           Vitória  2010.0  1.978263e+07        320156
# 3          MINAS GERAIS         Jacutinga  2010.0  2.478160e+05         21424
# 4                 PIAUÍ           Nazária  2010.0  2.095138e+04          7895
# ...                 ...               ...     ...           ...           ...
# 5561     SANTA CATARINA         Campo Erê  2010.0  1.876289e+05          9737
# 5562             PARANÁ          Planalto  2010.0  1.385535e+05         13983
# 5563          SÃO PAULO        Guararapes  2010.0  5.320191e+05         29639
# 5564  RIO GRANDE DO SUL  Barra do Guarita  2010.0  2.198064e+04          3067
# 5565  RIO GRANDE DO SUL        Machadinho  2010.0  5.715017e+04          5623
#
#       PIB_percapita                         Descrição               legenda  \
# 0       3140.239990  Produto Interno Bruto per capita             - 9639.65
# 1      11430.969727  Produto Interno Bruto per capita    9639.65 - 22144.80
# 2      61790.589844  Produto Interno Bruto per capita  52702.10 - 133669.00
# 3      11567.209961  Produto Interno Bruto per capita    9639.65 - 22144.80
# 4       2653.750000  Produto Interno Bruto per capita             - 9639.65
# ...             ...                               ...                   ...
# 5561   19269.679688  Produto Interno Bruto per capita    9639.65 - 22144.80
# 5562    9908.709961  Produto Interno Bruto per capita    9639.65 - 22144.80
# 5563   17949.970703  Produto Interno Bruto per capita    9639.65 - 22144.80
# 5564    7166.819824  Produto Interno Bruto per capita             - 9639.65
# 5565   10163.639648  Produto Interno Bruto per capita    9639.65 - 22144.80
#
#       classe                                               geom
# 0          1  MULTIPOLYGON (((-41.458803305191566 -14.781415...
# 1          2  MULTIPOLYGON (((-52.035349932081274 -31.567509...
# 2          4  MULTIPOLYGON (((-40.3292566978242 -20.23997417...
# 3          2  MULTIPOLYGON (((-46.50528160015326 -22.3400120...
# 4          1  POLYGON ((-42.826685407155495 -5.3480291684437...
# ...      ...                                                ...
# 5561       2  MULTIPOLYGON (((-53.024131281087385 -26.361357...
# 5562       2  MULTIPOLYGON (((-53.61882711231503 -25.6460599...
# 5563       2  MULTIPOLYGON (((-50.70271677275949 -21.0257124...
# 5564       1  MULTIPOLYGON (((-53.778785810369236 -27.152703...
# 5565       2  MULTIPOLYGON (((-51.63183373195086 -27.4885374...
#
# [5566 rows x 12 columns]

# %%
# manipule os dados

series_de_interesse = ['UF', 'nome', 'Pop_est_2009', 'PIB', 'PIB_percapita']

dados_limpos_cidades_df = pd.DataFrame(columns = series_de_interesse)

fonte_cidades.loc[(fonte_cidades['Censo']) == 2010]

for serie in series_de_interesse :
  dados_limpos_cidades_df[[serie]]= fonte_cidades[[serie]]

nome_das_series = ['estado', 'cidade', 'populacao', 'PIB', 'PIB_percapita']
dados_limpos_cidades_df.columns = nome_das_series

dados_limpos_cidades_df
# Out:
#                  estado            cidade  populacao           PIB  \
# 0                 BAHIA          Tremedal      18433  5.788399e+04
# 1     RIO GRANDE DO SUL            Turuçu       4000  4.572388e+04
# 2        ESPIRITO SANTO           Vitória     320156  1.978263e+07
# 3          MINAS GERAIS         Jacutinga      21424  2.478160e+05
# 4                 PIAUÍ           Nazária       7895  2.095138e+04
# ...                 ...               ...        ...           ...
# 5561     SANTA CATARINA         Campo Erê       9737  1.876289e+05
# 5562             PARANÁ          Planalto      13983  1.385535e+05
# 5563          SÃO PAULO        Guararapes      29639  5.320191e+05
# 5564  RIO GRANDE DO SUL  Barra do Guarita       3067  2.198064e+04
# 5565  RIO GRANDE DO SUL        Machadinho       5623  5.715017e+04
#
#       PIB_percapita
# 0       3140.239990
# 1      11430.969727
# 2      61790.589844
# 3      11567.209961
# 4       2653.750000
# ...             ...
# 5561   19269.679688
# 5562    9908.709961
# 5563   17949.970703
# 5564    7166.819824
# 5565   10163.639648
#
# [5566 rows x 5 columns]

# %%
# escrever o conteudo extraido no arquivo cidades-limpo.csv separados por ;

NOME_ARQUIVO_DESTINO ='cidades-limpo.csv'

dados_limpos_cidades_df.to_csv(NOME_ARQUIVO_DESTINO, sep=';', index=False)

# %% [markdown]
# ### **1.3. Brasil**

# %% [markdown]
# Utilize o pacote Python `pandas` para combinar os dados do arquivo `estados-limpo.csv` com os dados do arquivo `cidades-limpo.csv` em um único dataframe. Escolha a coluna e o método de combinação de tal forma que **não haja perda de dados** no processo (não produzirá valores nulos `NaN`). Salve os dados do dataframe no arquivo `brasil.csv`

# %%
# solução do exercício 1.3
# !pip install unidecode
from unidecode import unidecode

NOME_ARQUIVO_FONTE_CIDADES = 'cidades-bruto.csv'
NOME_ARQUIVO_FONTE_ESTADOS = 'estados-bruto.xml'

cidades_df = pd.read_csv(NOME_ARQUIVO_FONTE_CIDADES)
estados_df = pd.read_xml(NOME_ARQUIVO_FONTE_ESTADOS)

cidades_df = cidades_df.fillna('')
estados_df = estados_df.fillna('')

cidades_df.columns = cidades_df.columns.str.replace('UF', 'estado')
estados_df.columns = estados_df.columns.str.replace('NOME', 'estado')
# Out:
# Requirement already satisfied: unidecode in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
cidades_df['estado'] = cidades_df['estado'].apply(unidecode)

merged_df = pd.merge(left=cidades_df, right=estados_df, how='inner', on='estado')

merged_df

merged_df.to_csv('brasil.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Data Analytics

# %% [markdown]
# ### **2.1. DataFrame**

# %% [markdown]
# Utilize o pacote Python `pandas` para carregar o arquivo `brasil.csv` no dataframe `brasil_df`.

# %%
# solução do exercício 2.1
brasil_df = pd.read_csv('brasil.csv')
brasil_df
# Out:
#       Unnamed: 0                                              FID   gid  \
# 0              0  vw_pib_percapita.fid-4514e25a_17aaa325034_-258f   215
# 1              1  vw_pib_percapita.fid-4514e25a_17aaa325034_-2576  4559
# 2              2  vw_pib_percapita.fid-4514e25a_17aaa325034_-256b  4475
# 3              3  vw_pib_percapita.fid-4514e25a_17aaa325034_-2565  4459
# 4              4  vw_pib_percapita.fid-4514e25a_17aaa325034_-2561  4478
# ...          ...                                              ...   ...
# 5561        5561  vw_pib_percapita.fid-4514e25a_17aaa325034_-1187  1356
# 5562        5562  vw_pib_percapita.fid-4514e25a_17aaa325034_-103f  1361
# 5563        5563  vw_pib_percapita.fid-4514e25a_17aaa325034_-1009  1370
# 5564        5564   vw_pib_percapita.fid-4514e25a_17aaa325034_-f29  1364
# 5565        5565  vw_pib_percapita.fid-4514e25a_17aaa325034_-18fa   835
#
#                 estado                   nome   Censo           PIB  \
# 0                BAHIA               Tremedal  2010.0  5.788399e+04
# 1                BAHIA               Maetinga  2010.0  2.355845e+04
# 2                BAHIA               Ibirapuã  2010.0  7.499741e+04
# 3                BAHIA  Governador Mangabeira  2010.0  9.290382e+04
# 4                BAHIA                Ibititá  2010.0  6.236689e+04
# ...                ...                    ...     ...           ...
# 5561             AMAPA         Serra do Navio  2010.0  1.097953e+05
# 5562             AMAPA         Ferreira Gomes  2010.0  6.993773e+04
# 5563             AMAPA        Tartarugalzinho  2010.0  1.199880e+05
# 5564             AMAPA                 Macapá  2010.0  4.679694e+06
# 5565  DISTRITO FEDERAL               Brasília  2010.0  1.314873e+08
#
#       Pop_est_2009  PIB_percapita                         Descrição  \
# 0            18433    3140.239990  Produto Interno Bruto per capita
# 1             7884    2988.129883  Produto Interno Bruto per capita
# 2             7893    9501.759766  Produto Interno Bruto per capita
# 3            20668    4495.060059  Produto Interno Bruto per capita
# 4            19410    3213.129883  Produto Interno Bruto per capita
# ...            ...            ...                               ...
# 5561          3982   27572.900391  Produto Interno Bruto per capita
# 5562          5475   12774.009766  Produto Interno Bruto per capita
# 5563         13769    8714.360352  Produto Interno Bruto per capita
# 5564        366484   12769.160156  Produto Interno Bruto per capita
# 5565       2606885   50438.460938  Produto Interno Bruto per capita
#
#                   legenda  classe  \
# 0               - 9639.65       1
# 1               - 9639.65       1
# 2               - 9639.65       1
# 3               - 9639.65       1
# 4               - 9639.65       1
# ...                   ...     ...
# 5561  22144.80 - 52702.10       3
# 5562   9639.65 - 22144.80       2
# 5563            - 9639.65       1
# 5564   9639.65 - 22144.80       2
# 5565  22144.80 - 52702.10       3
#
#                                                    geom  ID  IDCAPITAL SIGLA  \
# 0     MULTIPOLYGON (((-41.458803305191566 -14.781415...   5        536    BA
# 1     MULTIPOLYGON (((-41.434440905792826 -14.551186...   5        536    BA
# 2     MULTIPOLYGON (((-40.1333701304941 -17.63887741...   5        536    BA
# 3     MULTIPOLYGON (((-39.008359369195716 -12.567865...   5        536    BA
# 4     MULTIPOLYGON (((-41.87084350357412 -11.4950176...   5        536    BA
# ...                                                 ...  ..        ...   ...
# 5561  MULTIPOLYGON (((-52.024338017088795 2.43550921...   3        131    AP
# 5562  MULTIPOLYGON (((-51.39188591230295 1.316958828...   3        131    AP
# 5563  MULTIPOLYGON (((-51.29572958019844 1.696799567...   3        131    AP
# 5564  MULTIPOLYGON (((-50.0580289939063 0.8424719447...   3        131    AP
# 5565  MULTIPOLYGON (((-47.3805248571471 -16.05027785...   7        916    DF
#
#             REGIAO
# 0         NORDESTE
# 1         NORDESTE
# 2         NORDESTE
# 3         NORDESTE
# 4         NORDESTE
# ...            ...
# 5561         NORTE
# 5562         NORTE
# 5563         NORTE
# 5564         NORTE
# 5565  CENTRO-OESTE
#
# [5566 rows x 17 columns]

# %% [markdown]
# ### **2.2. Analise**

# %% [markdown]
# Utilize o dataframe `brasil_df` para responder as seguintes perguntas de negócio:

# %% [markdown]
#  - Quais são as 10 cidades mais populosas do Brasil?

# %%
# código para responder a pergunta
brasil_df.sort_values(by = ['Pop_est_2009'], ascending=False, ignore_index=True).head(10)
# Out:
#    Unnamed: 0                                              FID   gid  \
# 0        3278  vw_pib_percapita.fid-4514e25a_17aaa325034_-1130  5088
# 1        4512  vw_pib_percapita.fid-4514e25a_17aaa325034_-227e  2001
# 2          44  vw_pib_percapita.fid-4514e25a_17aaa325034_-2388   124
# 3        5565  vw_pib_percapita.fid-4514e25a_17aaa325034_-18fa   835
# 4        4228  vw_pib_percapita.fid-4514e25a_17aaa325034_-12bf  2276
# 5        1736  vw_pib_percapita.fid-4514e25a_17aaa325034_-1162  2911
# 6        4860  vw_pib_percapita.fid-4514e25a_17aaa325034_-1de7  5136
# 7        3727  vw_pib_percapita.fid-4514e25a_17aaa325034_-2442  1572
# 8        2439  vw_pib_percapita.fid-4514e25a_17aaa325034_-1695   253
# 9        2628  vw_pib_percapita.fid-4514e25a_17aaa325034_-1005  2213
#
#              estado            nome   Censo          PIB  Pop_est_2009  \
# 0         SAO PAULO       São Paulo  2010.0  389317152.0      11037593
# 1    RIO DE JANEIRO  Rio de Janeiro  2010.0  175739344.0       6186710
# 2             BAHIA        Salvador  2010.0   32824228.0       2998056
# 3  DISTRITO FEDERAL        Brasília  2010.0  131487264.0       2606885
# 4             CEARA       Fortaleza  2010.0   31789186.0       2505552
# 5      MINAS GERAIS  Belo Horizonte  2010.0   44595204.0       2452617
# 6            PARANA        Curitiba  2010.0   45762420.0       1851215
# 7          AMAZONAS          Manaus  2010.0   40486108.0       1738641
# 8        PERNAMBUCO          Recife  2010.0   24835340.0       1561659
# 9              PARA           Belém  2010.0   16526989.0       1437600
#
#    PIB_percapita                         Descrição              legenda  \
# 0   35271.929688  Produto Interno Bruto per capita  22144.80 - 52702.10
# 1   28405.949219  Produto Interno Bruto per capita  22144.80 - 52702.10
# 2   10948.500000  Produto Interno Bruto per capita   9639.65 - 22144.80
# 3   50438.460938  Produto Interno Bruto per capita  22144.80 - 52702.10
# 4   12687.500000  Produto Interno Bruto per capita   9639.65 - 22144.80
# 5   18182.699219  Produto Interno Bruto per capita   9639.65 - 22144.80
# 6   24720.210938  Produto Interno Bruto per capita  22144.80 - 52702.10
# 7   23286.060547  Produto Interno Bruto per capita  22144.80 - 52702.10
# 8   15903.179688  Produto Interno Bruto per capita   9639.65 - 22144.80
# 9   11496.240234  Produto Interno Bruto per capita   9639.65 - 22144.80
#
#    classe                                               geom  ID  IDCAPITAL  \
# 0       3  MULTIPOLYGON (((-46.53616590160792 -23.3625463...  24       4361
# 1       3  MULTIPOLYGON (((-43.109141023447734 -22.768805...  18       2779
# 2       2  MULTIPOLYGON (((-38.622239087346124 -12.751296...   5        536
# 3       3  MULTIPOLYGON (((-47.3805248571471 -16.05027785...   7        916
# 4       2  MULTIPOLYGON (((-38.42283838031695 -3.81699225...   6        676
# 5       2  MULTIPOLYGON (((-43.94578447883935 -19.7767905...  27       4790
# 6       3  MULTIPOLYGON (((-49.233532767600124 -25.350653...  15       2002
# 7       3  MULTIPOLYGON (((-60.001611142130734 -2.1191118...   4        178
# 8       2  MULTIPOLYGON (((-34.9913687601354 -7.936765643...  16       2439
# 9       2  MULTIPOLYGON (((-48.30138694444446 -1.10599777...  13       1561
#
#   SIGLA        REGIAO
# 0    SP       SUDESTE
# 1    RJ       SUDESTE
# 2    BA      NORDESTE
# 3    DF  CENTRO-OESTE
# 4    CE      NORDESTE
# 5    MG       SUDESTE
# 6    PR           SUL
# 7    AM         NORTE
# 8    PE      NORDESTE
# 9    PA         NORTE

# %% [markdown]
#  - Quais são as 5 cidades com a menor PIB per capita da região nordeste?

# %%
# código para responder a pergunta
brasil_df.query('REGIAO == "NORDESTE"').sort_values(by= ['PIB_percapita'], ignore_index=True).head()
# Out:
#    Unnamed: 0                                              FID   gid  \
# 0        4471  vw_pib_percapita.fid-4514e25a_17aaa325034_-11ba  2496
# 1        4366  vw_pib_percapita.fid-4514e25a_17aaa325034_-1c3c  2127
# 2          69  vw_pib_percapita.fid-4514e25a_17aaa325034_-2244  2192
# 3        1849  vw_pib_percapita.fid-4514e25a_17aaa325034_-2528  1090
# 4        4491   vw_pib_percapita.fid-4514e25a_17aaa325034_-f64  2525
#
#      estado                nome   Censo           PIB  Pop_est_2009  \
# 0  MARANHAO  São Vicente Ferrer  2010.0  39492.960938         20463
# 1  MARANHAO             Cajapió  2010.0  22781.035156         10337
# 2     BAHIA             Lamarão     NaN  30241.320312         12995
# 3     PIAUI       Dom Inocêncio  2010.0  25457.230469         10795
# 4  MARANHAO            Timbiras  2010.0  63724.851562         26909
#
#    PIB_percapita                         Descrição     legenda  classe  \
# 0    1929.969971  Produto Interno Bruto per capita   - 9639.65       1
# 1    2203.830078  Produto Interno Bruto per capita   - 9639.65       1
# 2    2327.149902  Produto Interno Bruto per capita   - 9639.65       1
# 3    2358.239990  Produto Interno Bruto per capita   - 9639.65       1
# 4    2368.159912  Produto Interno Bruto per capita   - 9639.65       1
#
#                                                 geom  ID  IDCAPITAL SIGLA  \
# 0  MULTIPOLYGON (((-44.820975515987854 -2.8021265...  10       1309    MA
# 1  MULTIPOLYGON (((-44.427988387368124 -2.7099774...  10       1309    MA
# 2  MULTIPOLYGON (((-38.831295946714796 -11.773438...   5        536    BA
# 3  MULTIPOLYGON (((-42.11223400164648 -8.58192312...  17       2704    PI
# 4  MULTIPOLYGON (((-43.66623800794751 -3.99985689...  10       1309    MA
#
#      REGIAO
# 0  NORDESTE
# 1  NORDESTE
# 2  NORDESTE
# 3  NORDESTE
# 4  NORDESTE

# %% [markdown]
#  - Quais são as 15 cidades com maior PIB do do estado de São Paulo?

# %%
# código para responder a pergunta
brasil_df.loc[brasil_df['estado'] == 'SAO PAULO'].sort_values(by= ['PIB'], ignore_index=True, ascending=False).loc[0:14]
# Out:
#     Unnamed: 0                                              FID   gid  \
# 0         3278  vw_pib_percapita.fid-4514e25a_17aaa325034_-1130  5088
# 1         3230  vw_pib_percapita.fid-4514e25a_17aaa325034_-1308  5046
# 2         3347   vw_pib_percapita.fid-4514e25a_17aaa325034_-f37  4964
# 3         3112  vw_pib_percapita.fid-4514e25a_17aaa325034_-170a  5065
# 4         2815  vw_pib_percapita.fid-4514e25a_17aaa325034_-21ba  1679
# 5         3351   vw_pib_percapita.fid-4514e25a_17aaa325034_-f18  5004
# 6         2772  vw_pib_percapita.fid-4514e25a_17aaa325034_-234f  5086
# 7         2999  vw_pib_percapita.fid-4514e25a_17aaa325034_-1b2d  5134
# 8         3019  vw_pib_percapita.fid-4514e25a_17aaa325034_-1a69  5058
# 9         2821  vw_pib_percapita.fid-4514e25a_17aaa325034_-2189  1613
# 10        2758  vw_pib_percapita.fid-4514e25a_17aaa325034_-23cb    33
# 11        3159  vw_pib_percapita.fid-4514e25a_17aaa325034_-1546  1768
# 12        3043  vw_pib_percapita.fid-4514e25a_17aaa325034_-19a3  2009
# 13        3341   vw_pib_percapita.fid-4514e25a_17aaa325034_-f52  4739
# 14        3004  vw_pib_percapita.fid-4514e25a_17aaa325034_-1af1  1680
#
#        estado                   nome   Censo          PIB  Pop_est_2009  \
# 0   SAO PAULO              São Paulo  2010.0  389317152.0      11037593
# 1   SAO PAULO              Guarulhos  2010.0   32473828.0       1299283
# 2   SAO PAULO               Campinas  2010.0   31654720.0       1064669
# 3   SAO PAULO                 Osasco  2010.0   31616452.0        718646
# 4   SAO PAULO  São Bernardo do Campo  2010.0   28935768.0        810979
# 5   SAO PAULO                Barueri  2010.0   26908070.0        270173
# 6   SAO PAULO                 Santos  2010.0   22546134.0        417098
# 7   SAO PAULO    São José dos Campos  2010.0   22018042.0        615871
# 8   SAO PAULO                Jundiaí  2010.0   16585137.0        349929
# 9   SAO PAULO            Santo André  2010.0   14709603.0        673396
# 10  SAO PAULO         Ribeirão Preto  2010.0   14688064.0        563107
# 11  SAO PAULO               Sorocaba  2010.0   14182597.0        584313
# 12  SAO PAULO                Diadema  2010.0    9969819.0        397738
# 13  SAO PAULO             Piracicaba  2010.0    9601211.0        368843
# 14  SAO PAULO     São Caetano do Sul  2010.0    8920202.0        152093
#
#     PIB_percapita                         Descrição               legenda  \
# 0    35271.929688  Produto Interno Bruto per capita   22144.80 - 52702.10
# 1    24993.650391  Produto Interno Bruto per capita   22144.80 - 52702.10
# 2    29731.980469  Produto Interno Bruto per capita   22144.80 - 52702.10
# 3    43994.468750  Produto Interno Bruto per capita   22144.80 - 52702.10
# 4    35680.050781  Produto Interno Bruto per capita   22144.80 - 52702.10
# 5    99595.703125  Produto Interno Bruto per capita  52702.10 - 133669.00
# 6    54054.761719  Produto Interno Bruto per capita  52702.10 - 133669.00
# 7    35751.058594  Produto Interno Bruto per capita   22144.80 - 52702.10
# 8    47395.718750  Produto Interno Bruto per capita   22144.80 - 52702.10
# 9    21843.910156  Produto Interno Bruto per capita    9639.65 - 22144.80
# 10   26083.970703  Produto Interno Bruto per capita   22144.80 - 52702.10
# 11   24272.259766  Produto Interno Bruto per capita   22144.80 - 52702.10
# 12   25066.300781  Produto Interno Bruto per capita   22144.80 - 52702.10
# 13   26030.619141  Produto Interno Bruto per capita   22144.80 - 52702.10
# 14   58649.648438  Produto Interno Bruto per capita  52702.10 - 133669.00
#
#     classe                                               geom  ID  IDCAPITAL  \
# 0        3  MULTIPOLYGON (((-46.53616590160792 -23.3625463...  24       4361
# 1        3  MULTIPOLYGON (((-46.35729098920982 -23.3248492...  24       4361
# 2        3  MULTIPOLYGON (((-46.90107908421256 -22.7654838...  24       4361
# 3        3  MULTIPOLYGON (((-46.7777279871156 -23.46460916...  24       4361
# 4        3  MULTIPOLYGON (((-46.564455514581 -23.647633414...  24       4361
# 5        4  MULTIPOLYGON (((-46.79712466707602 -23.4684027...  24       4361
# 6        4  MULTIPOLYGON (((-46.2242826669002 -23.74234770...  24       4361
# 7        3  MULTIPOLYGON (((-45.8722455727497 -22.86649804...  24       4361
# 8        3  MULTIPOLYGON (((-46.79160581372197 -23.1009531...  24       4361
# 9        2  MULTIPOLYGON (((-46.535091604708214 -23.612465...  24       4361
# 10       3  MULTIPOLYGON (((-47.716523159116925 -21.117740...  24       4361
# 11       3  MULTIPOLYGON (((-47.426892876716 -23.358625445...  24       4361
# 12       3  MULTIPOLYGON (((-46.61590257583677 -23.6575183...  24       4361
# 13       3  MULTIPOLYGON (((-47.58229321800234 -22.5414663...  24       4361
# 14       4  MULTIPOLYGON (((-46.54488325485447 -23.6077791...  24       4361
#
#    SIGLA   REGIAO
# 0     SP  SUDESTE
# 1     SP  SUDESTE
# 2     SP  SUDESTE
# 3     SP  SUDESTE
# 4     SP  SUDESTE
# 5     SP  SUDESTE
# 6     SP  SUDESTE
# 7     SP  SUDESTE
# 8     SP  SUDESTE
# 9     SP  SUDESTE
# 10    SP  SUDESTE
# 11    SP  SUDESTE
# 12    SP  SUDESTE
# 13    SP  SUDESTE
# 14    SP  SUDESTE

# %% [markdown]
#  - Qual é o PIB do estado de Santa Catarina?

# %%
# código para responder a pergunta
brasil_df.loc[brasil_df['estado'] == 'SANTA CATARINA']['PIB'].agg('sum')
# Out:
# 129806256.75195317

# %% [markdown]
#  - Qual é o população da região sul?

# %%
# código para responder a pergunta
brasil_df.loc[brasil_df['REGIAO'] == 'SUL']['Pop_est_2009'].agg('sum')
# Out:
# 27719118

# %% [markdown]
#  - Qual é o PIB per capito médio das cidades do Mato Grosso do Sul?

# %%
# código para responder a pergunta
brasil_df.loc[brasil_df['estado'] == 'MATO GROSSO DO SUL']['PIB_percapita'].agg('mean')
# Out:
# 14458.896859975644

# %% [markdown]
#  - Qual é a população do Brasil?

# %%
# código para responder a pergunta
brasil_df['Pop_est_2009'].agg('sum')
# Out:
# 191501418

# %% [markdown]
# ### **2.3. Visualização**

# %% [markdown]
# Utilize o dataframe `brasil_df` para gerar as seguintes visualizações.

# %% [markdown]
#  - Gere um gráfico de barras com as 10 cidades menos populosas do Brasil.

# %%
# código para gerar a visualização

plot_10menospop_df = brasil_df.sort_values(by= ['Pop_est_2009'], ignore_index=True).head(10)[['nome', 'Pop_est_2009']]

plot_10menospop_df.plot.bar(x='nome', y='Pop_est_2009', figsize=(11,6))
# Out:
# <Axes: xlabel='nome'>

# %% [markdown]
#  - Gere um gráfico de pizza com a proporção da população do Brasil por região.

# %%
# código para gerar a visualização

plot_pop_regiao_df = brasil_df[['REGIAO','Pop_est_2009']].groupby(by='REGIAO').agg('sum')

plot_pop_regiao_df.plot.pie(y='Pop_est_2009', figsize=(14, 11))
# Out:
# <Axes: ylabel='Pop_est_2009'>
