# %% [markdown]
# <a href="https://colab.research.google.com/github/maycgr/Analise-De-Dados-EBAC/blob/main/modulo_38_exercicio_mayara.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Criando o arquivo csv.**

# %%
import pandas as pd
import seaborn as sns

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.to_csv('iris.csv', index= False, header= False)

# %% [markdown]
# Com o arquivo csv já criado e importado para o bucket no s3 criei e table iris no AWS athena.
#
# query:
#
# ![criandotabela.png](data:image/png;base64,...)

# %% [markdown]
# Com a tabela ja criada selecionei as 10 primeiras linhas do dataset.
#
# query:
#
# ![query1.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query1results.png](data:image/png;base64,...)

# %% [markdown]
# Selecionei apenas as especies de iris.
#
# query:
#
# ![query2.png](data:image/png;base64,...)
#
# Resuldo:
#
# ![query2results.png](data:image/png;base64,...)

# %% [markdown]
# Também fiz a contagem de linhas do dataset.
#
# query:
#
# ![query3.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query3results.png](data:image/png;base64,...)

# %% [markdown]
# E como um exemplo selecionei apenas a coluna petal_lenght limitado em 10 linhas.
#
# query:
#
# ![query4.png](data:image/png;base64,...)
#
# Resultado:
#
# ![query4results.png](data:image/png;base64,...)
